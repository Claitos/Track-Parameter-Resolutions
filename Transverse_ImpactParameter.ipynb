# %%
import numpy as np
import matplotlib.pyplot as plt
from function_library import *

# %%
directory = "Transverse_ImpactParameter_Plots"

# %% [markdown]
# #### Proton:
# - transverse impact parameter resolution
# - for different extraplation radii (0.025, 0.075, 0.125) m
# - for different momenta ( 0 - 4 GeV/c )
# - for different polar angles (90°, 67.5°, 45°)
# - 4 hits in the outer layers of the ITS2

# %%
proton_momenta = np.arange(0.25, 4, 0.25)                   # momentum of particle in GeV/c
proton_mass = 1                                             # mass of particle in GeV/c^2 

N = 4                                                       # Number of layers with hits
extrapolation_radii = [0.025, 0.075, 0.125]                 # extrapolation length in meters (is defined away from layers) ;
theta_list = [90, 67.5, 45]                                 # polar angles of the particle

proton_rphi_det_list = []
proton_rphi_MS_list = []
for r in extrapolation_radii:
    proton_rphi_det = []; proton_rphi_MS = []
    for momentum in proton_momenta:
        rphi_det, rphi_MS = transverse_impactparameter_reso(momentum, proton_mass, N, r)
        proton_rphi_det.append(rphi_det); proton_rphi_MS.append(rphi_MS)
    proton_rphi_det_list.append(np.array(proton_rphi_det))
    proton_rphi_MS_list.append(np.array(proton_rphi_MS))

# %%
for i, r in enumerate(extrapolation_radii):
    proton_rphi_list = total_transverse_resolution(proton_rphi_det_list[i], proton_rphi_MS_list[i], theta_list[0])
    plt.plot(proton_momenta, proton_rphi_list*100, ".", label=f"extrapolation distance = {r*100} cm")
plt.legend()
plt.xlabel("$p_{T}$ [GeV/c]")
plt.ylabel("$\sigma_{r \phi}$ [cm]")
plt.ylim(0, 0.15)
plt.text(2.5, 0.1, "Proton with 4 hits")
plt.text(2.5, 0.095, fr"$\theta = 90$°")
plt.tick_params(top=True, right=True, direction="in")
plt.savefig(f"{directory}/Proton_rphi.png", dpi = 200)

# %%
fig, axs = plt.subplots(1,3, figsize=(16,5))

for i, theta in enumerate(theta_list):
    for j, radius in enumerate(extrapolation_radii):
        proton_rphi_list = total_transverse_resolution(proton_rphi_det_list[j], proton_rphi_MS_list[j], theta)
        axs[i].plot(proton_momenta, proton_rphi_list*100, ".", label=f"extraplation radius = {radius*100} cm")

for i, ax in enumerate(axs):
    ax.set(xlabel="$p_{T}$ [GeV/c]", ylabel = "$\sigma_{r \phi}$ [cm]", ylim=(0, 0.15))
    ax.tick_params(top=True, right=True, direction="in")
    ax.text(2.5, 0.1, "Proton with 4 hits")
    ax.text(2.5, 0.095, fr"$\theta = {theta_list[i]}$°")

axs[1].legend(loc=(0.25, 0.8))
fig.savefig(f"{directory}/Proton_rphi_angle.png", dpi = 200)

# %% [markdown]
# #### Pion:
# - transverse impact parameter resolution
# - for different extraplation radii (0.025, 0.075, 0.125) m
# - for different momenta ( 0 - 1 GeV/c)
# - for different polar angles (90°, 67.5°, 45°)
# - 4 hits in the outer layers of the ITS2

# %%
pion_momenta = np.arange(0.1, 1.1, 0.1)                     # momentum of particle in GeV/c
pion_mass = 0.150                                           # mass of particle in GeV/c^2 

N = 4                                                       # Number of layers with hits
extrapolation_radii = [0.025, 0.075, 0.125]                 # extrapolation length in meters (is defined away from layers) ;
theta_list = [90, 67.5, 45]                                 # polar angles of the particle

pion_rphi_det_list = []
pion_rphi_MS_list = []
for r in extrapolation_radii:
    pion_rphi_det = []; pion_rphi_MS = []
    for momentum in pion_momenta:
        rphi_det, rphi_MS = transverse_impactparameter_reso(momentum, pion_mass, N, r)
        pion_rphi_det.append(rphi_det); pion_rphi_MS.append(rphi_MS)
    pion_rphi_det_list.append(np.array(pion_rphi_det))
    pion_rphi_MS_list.append(np.array(pion_rphi_MS))

# %%
for i, r in enumerate(extrapolation_radii):
    pion_rphi_list = total_transverse_resolution(pion_rphi_det_list[i], pion_rphi_MS_list[i], theta_list[0])
    plt.plot(pion_momenta, pion_rphi_list*100, ".", label=f"extrapolation distance = {r*100} cm")
plt.legend()
plt.xlabel("$p_{T}$ [GeV/c]")
plt.ylabel("$\sigma_{r \phi}$ [cm]")
plt.ylim(0, 0.15)
plt.text(0.7, 0.1, "Pion with 4 hits")
plt.text(0.7, 0.095, fr"$\theta = 90$°")
plt.tick_params(top=True, right=True, direction="in")
plt.savefig(f"{directory}/Pion_rphi.png", dpi = 200)

# %%
fig, axs = plt.subplots(1,3, figsize=(16,5))

for i, theta in enumerate(theta_list):
    for j, radius in enumerate(extrapolation_radii):
        pion_rphi_list = total_transverse_resolution(pion_rphi_det_list[j], pion_rphi_MS_list[j], theta)
        axs[i].plot(pion_momenta, pion_rphi_list*100, ".", label=f"extraplation radius = {radius*100} cm")

for i, ax in enumerate(axs):
    ax.set(xlabel="$p_{T}$ [GeV/c]", ylabel = "$\sigma_{r \phi}$ [cm]", ylim=(0, 0.15))
    ax.tick_params(top=True, right=True, direction="in")
    ax.text(0.7, 0.1, "Pion with 4 hits")
    ax.text(0.7, 0.095, fr"$\theta = {theta_list[i]}$°")

axs[1].legend(loc=(0.25, 0.8))
fig.savefig(f"{directory}/Pion_rphi_angle.png", dpi = 200)

# %% [markdown]
# #### Proton:
# - transverse impact parameter resolution
# - for different extraplation radii 1 cm
# - for different momenta ( 0 - 4 GeV/c )
# - for different polar angles (90°, 67.5°, 45°)
# - ### 7 hits in the ITS2

# %%
proton_momenta = np.arange(0.25, 4, 0.25)                   # momentum of particle in GeV/c
proton_mass = 1                                             # mass of particle in GeV/c^2 

N = 7                                                       # Number of layers with hits
extrapolation_radius = 0.01                                 # extrapolation length in meters (is defined away from layers) ;
theta_list = [90, 67.5, 45]                                 # polar angles of the particle

proton_rphi_det_list = []
proton_rphi_MS_list = []
for momentum in proton_momenta:
    rphi_det, rphi_MS = transverse_impactparameter_reso(momentum, proton_mass, N, extrapolation_radius)
    proton_rphi_det_list.append(rphi_det); proton_rphi_MS_list.append(rphi_MS)
    
proton_rphi_det_list = np.array(proton_rphi_det_list)
proton_rphi_MS_list = np.array(proton_rphi_MS_list)

# %%
for theta in theta_list:
    proton_rphi_list = total_transverse_resolution(proton_rphi_det_list, proton_rphi_MS_list, theta)
    plt.plot(proton_momenta, proton_rphi_list*10**6, ".", label=f"polarangle = {theta} °")
plt.legend()
plt.ylim(0, 150)
plt.xlabel("$p_{T}$ [GeV/c]")
plt.ylabel("$\sigma_{r \phi}$ [$\mu m $]")
plt.text(2.3, 100, "Proton with 7 hits")
plt.text(2.3, 90, "extrapolation radius = 1cm")
plt.tick_params(top=True, right=True, direction="in")
plt.savefig(f"{directory}/Proton_rphi_7.png", dpi = 200)

# %% [markdown]
# #### Pion:
# - transverse impact parameter resolution
# - for different extraplation radii 1 cm
# - for different momenta ( 0 - 1 GeV/c)
# - for different polar angles (90°, 67.5°, 45°)
# - #### 7 hits in the ITS2

# %%
pion_momenta = np.arange(0.1, 1.1, 0.1)                     # momentum of particle in GeV/c
pion_mass = 0.150                                           # mass of particle in GeV/c^2 

N = 7                                                       # Number of layers with hits
extrapolation_radius = 0.01                                  # extrapolation length in meters (is defined away from layers) ;
theta_list = [90, 67.5, 45]                                 # polar angles of the particle

pion_rphi_det_list = []
pion_rphi_MS_list = []
for momentum in pion_momenta:
    rphi_det, rphi_MS = transverse_impactparameter_reso(momentum, pion_mass, N, extrapolation_radius)
    pion_rphi_det_list.append(rphi_det); pion_rphi_MS_list.append(rphi_MS)
    
pion_rphi_det_list = np.array(pion_rphi_det_list)
pion_rphi_MS_list = np.array(pion_rphi_MS_list)

# %%
for theta in theta_list:
    pion_rphi_list = total_transverse_resolution(pion_rphi_det_list, pion_rphi_MS_list, theta)
    plt.plot(pion_momenta, pion_rphi_list*10**6, ".", label=f"polarangle = {theta} °")
plt.legend()
plt.ylim(0, 150)
plt.xlabel("$p_{T}$ [GeV/c]")
plt.ylabel("$\sigma_{r \phi}$ [$\mu m $]")
plt.text(0.6, 100, "Pion with 7 hits")
plt.text(0.6, 90, "extrapolation radius = 1cm")
plt.tick_params(top=True, right=True, direction="in")
plt.savefig(f"{directory}/Pion_rphi_7.png", dpi = 200)
